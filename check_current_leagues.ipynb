# %%
from mwrogue.esports_client import EsportsClient
import datetime as dt
import pandas as pd

# %%
site = EsportsClient("lol")
response = site.cargo_client.query(
    tables="CurrentLeagues=CL",
    fields="CL.Event, CL.OverviewPage"
)

# %%
response
# Out:
# [OrderedDict([('Event', 'Asia Masters 2025 Swiss 2'),
#               ('OverviewPage', '2025 Asia Masters/Swiss 2')]),
#  OrderedDict([('Event', 'Empoliga Major A 2025 Split 2'),
#               ('OverviewPage', 'Empoliga/Major A/2025 Season/Split 2 Major')]),
#  OrderedDict([('Event', 'Equal Esports Cup 2025 Group Stage'),
#               ('OverviewPage', 'Equal Esports Cup 2025/Group Stage')]),
#  OrderedDict([('Event', 'Esports World Cup 2025'),
#               ('OverviewPage', 'Esports World Cup 2025')]),
#  OrderedDict([('Event', 'LCK 2025 Rounds 3-5'),
#               ('OverviewPage', 'LCK/2025 Season/Rounds 3-5')]),
#  OrderedDict([('Event', 'LigaGG CELOL A 2025 Split 1 Playoffs'),
#               ('OverviewPage',
#                'LigaGG/CELOL Série A/2025 Season/Split 1 Playoffs')]),
#  OrderedDict([('Event', 'MSI 2025'),
#               ('OverviewPage', '2025 Mid-Season Invitational')]),
#  OrderedDict([('Event', 'PCS 2025 Split 3'),
# ...
